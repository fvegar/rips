# %% [markdown]
# ## Dipersion relation for small $k$

# %%
det_lin2_k(Gamma_u, Gamma_w, Re_R) = Gamma_u*Gamma_w*k^2 + I*((2*Gamma_u + Gamma_w) + 1/Re_R)*w^3 + w^4 - (Gamma_u^2 + 2*Gamma_u*Gamma_w + k^2 + 2*Gamma_u/Re_R - k^2/(4*Re_R^2))*w^2 + Gamma_u*k^2/Re_R - (I*Gamma_u^2*Gamma_w + I*(Gamma_u + Gamma_w)*k^2 + I*Gamma_u^2/Re_R - I*Gamma_u*k^2/(4*Re_R^2) + I*k^2/Re_R)*w
det_lin2_k(Gamma_u, Gamma_w, Re_R)
# Out:
# Gamma_u*Gamma_w*k^2 + (2*I*Gamma_u + I*Gamma_w + I/Re_R)*w^3 + w^4 - 1/4*(4*Gamma_u^2 + 8*Gamma_u*Gamma_w + 4*k^2 + 8*Gamma_u/Re_R - k^2/Re_R^2)*w^2 + Gamma_u*k^2/Re_R + 1/4*(-4*I*Gamma_u^2*Gamma_w - 4*(I*Gamma_u + I*Gamma_w)*k^2 - 4*I*Gamma_u^2/Re_R + I*Gamma_u*k^2/Re_R^2 - 4*I*k^2/Re_R)*w

# %% [markdown]
# ## Dispersion limit, from equation above for $\mathrm{Re}_R\to 0.0$: $\omega = -i\, \Gamma_u$
# ### since $\Gamma_u>0$ thus $\mathrm{Im}(\omega)<0$ and therefore there are no unstable points in the limit of very small spin rate

# %% [markdown]
# ## Dispersion curves for $\mathrm{Re}_R=0.01$ (all curves $\Gamma_u, \Gamma_w=1$)

# %%
# Re_R = 0.01
G.show(ymin=-2)
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [markdown]
# ## Dispersion curves for $\mathrm{Re}_R=0.05$

# %%
# Re_R = 0.05
G.show(ymin=-2)
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [markdown]
# ## Dispersion curves for $\mathrm{Re}_R=0.1$

# %%
# Re_R =0.1
G.show(ymin=-2)
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [markdown]
# ## Dispersion curves for $\mathrm{Re}_R=0.25$

# %%
# Re_R=0.25
G.show(ymin=-2)
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [markdown]
# ## Dispersion curves for $\mathrm{Re}_R=\infty$

# %%
# Re_R = oo
G.show(ymin=-2)
# Out:
# Graphics object consisting of 4 graphics primitives
